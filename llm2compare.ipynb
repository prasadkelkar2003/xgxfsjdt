# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="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",
)

completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1:novita",
    messages=[
        {
            "role": "user",
            "content": "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='<think>\nOkay, let\'s see. The question is asking which planet is known as the Red Planet. The options are Earth, Mars, Jupiter, and Venus. Hmm, I remember from school that Mars is often called the Red Planet. But wait, why is that? Maybe because of its reddish appearance in the sky? I think that\'s due to iron oxide, like rust, on its surface. Let me double-check. Earth is called the Blue Planet because of the water. Jupiter is a gas giant, mostly bands of color but not red. Venus is often referred to as the Morning Star or Evening Star but not red. So yeah, Mars must be the correct answer. Let me confirm quickly. Yeah, Mars is the Red Planet. So the answer is B.\n</think>\n\n\n\nThe planet known as the Red Planet is **B. Mars**. Its reddish appearance is caused by iron oxide (rust) on its surface. Other options are incorrect:  \n- **A. Earth** is the "Blue Planet" due to its oceans.  \n- **C. Jupiter** is a gas giant with striped cloud bands.  \n- **D
# ...

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="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",  # Replace with actual key
)

completion = client.chat.completions.create(
    model="microsoft/phi-4:nebius",
    messages=[
        {
            "role": "user",
            "content": "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='B. Mars\n\nMars is commonly referred to as the Red Planet due to its reddish appearance, which is caused by iron oxide, or rust, on its surface.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning_content=None)

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="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",
)

completion = client.chat.completions.create(
    model="nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together",
    messages=[
        {
            "role": "user",
            "content": "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='A simple and classic question!\n\nThe correct answer is:\n\n**B. Mars**\n\nExplanation: Mars is commonly known as the "Red Planet" due to its reddish appearance, which is caused by iron oxide (or rust) in the planet\'s soil and rocks. This distinctive coloration is visible from Earth and has been observed by numerous spacecraft that have imaged Mars over the years.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[])

# %%
from openai import OpenAI

# Replace with your actual Hugging Face API key
api_key = "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"

# Create client for both models using same API key and base URL
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=api_key
)

# The MCQ prompt
prompt = "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"

# List of models to query
models = [
    "microsoft/phi-4:nebius",
    "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
]

# Loop through each model and get completion
for model in models:
    print(f"\n--- Response from {model} ---")
    try:
        completion = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ],
        )
        print(completion.choices[0].message.content)
    except Exception as e:
        print(f"Error with {model}:", e)
# Out:
# --- Response from microsoft/phi-4:nebius ---
# B. Mars
#
# Mars is known as the Red Planet due to its reddish appearance, which is the result of iron oxide, or rust, on its surface.
#
# --- Response from nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together ---
# A simple and classic astronomy question!
#
# The correct answer is:
#
# **B. Mars**
#
# Explanation: Mars is commonly known as the "Red Planet" due to its distinctive reddish appearance, which is caused by iron oxide (or rust) in the planet's soil and rocks. This gives Mars its characteristic reddish hue, making it stand out in our solar system.

# %%
from openai import OpenAI

# Replace with your actual Hugging Face API key
api_key = "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"

# Create client for Hugging Face Inference Endpoints
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=api_key
)

# The MCQ question
prompt = "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"

# Model names
models = {
    "Phi-4": "microsoft/phi-4:nebius",
    "Nemotron": "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
}

# Dictionary to store each model's answer
answers = {}

# Collect answers from both models
for name, model_id in models.items():
    try:
        response = client.chat.completions.create(
            model=model_id,
            messages=[{"role": "user", "content": prompt}]
        )
        answer = response.choices[0].message.content.strip()
        answers[name] = answer
    except Exception as e:
        answers[name] = f"Error: {e}"

# Compare answers
print("\n🔍 Comparison of Answers:\n")

# If both agree (match ignoring case and whitespace)
vals = list(answers.values())
if len(set([ans.lower().strip() for ans in vals])) == 1:
    print(f"✅ Both LLMs agree:\n\n{vals[0]}")
else:
    print("⚠️ LLMs gave different answers:\n")
    for name, answer in answers.items():
        print(f"{name} ➜ {answer}")
# Out:
# 🔍 Comparison of Answers:
#
# ⚠️ LLMs gave different answers:
#
# Phi-4 ➜ B. Mars
#
# Mars is known as the Red Planet due to its reddish appearance, which is caused by iron oxide, commonly known as rust, on its surface.
# Nemotron ➜ A simple and classic astronomy question!
#
# The correct answer is:
#
# **B. Mars**
#
# Explanation: Mars is commonly known as the "Red Planet" due to its distinctive reddish appearance, which is caused by iron oxide (or rust) in the planet's soil and rocks. This gives Mars its characteristic reddish hue, making it stand out in our solar system.

# %%
import os
import numpy as np
from openai import OpenAI
import requests

# Replace this with your actual Hugging Face token
HF_TOKEN = "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"

# Initialize LLM API client
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=HF_TOKEN,
)

# Prompt to ask both LLMs
question = "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"

# Two model names
models = {
    "Phi-4": "microsoft/phi-4:nebius",
    "Nemotron": "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
}

# Step 1: Ask both LLMs
answers = {}
for name, model_id in models.items():
    try:
        response = client.chat.completions.create(
            model=model_id,
            messages=[{"role": "user", "content": question}]
        )
        ans = response.choices[0].message.content.strip()
        answers[name] = ans
    except Exception as e:
        answers[name] = f"Error: {e}"

# Step 2: Embed the answers using Hugging Face API
def get_embedding(text):
    url = "https://api-inference.huggingface.co/pipeline/feature-extraction/sentence-transformers/all-MiniLM-L6-v2"
    headers = {"Authorization": f"Bearer {HF_TOKEN}"}
    response = requests.post(url, headers=headers, json={"inputs": text})
    response.raise_for_status()
    return np.array(response.json()[0])

# Get embeddings
embedding_1 = get_embedding(list(answers.values())[0])
embedding_2 = get_embedding(list(answers.values())[1])

# Step 3: Compute cosine similarity
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

similarity = cosine_similarity(embedding_1, embedding_2)

# Step 4: Decide based on similarity
print("\n🔍 Comparison of Answers:\n")
if similarity > 0.9:
    print(f"✅ Both LLMs agree (similarity: {similarity:.2f}):\n\n{list(answers.values())[0]}")
else:
    print(f"⚠️ LLMs differ (similarity: {similarity:.2f}):\n")
    for name, answer in answers.items():
        print(f"{name} ➜ {answer}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-17-2856793956.py in <cell line: 0>()
#      44
#      45 # Get embeddings
# ---> 46 embedding_1 = get_embedding(list(answers.values())[0])
#      47 embedding_2 = get_embedding(list(answers.values())[1])
#      48
#
# /tmp/ipython-input-17-2856793956.py in get_embedding(text)
#      40     headers = {"Authorization": f"Bearer {HF_TOKEN}"}
#      41     response = requests.post(url, headers=headers, json={"inputs": text})
# ---> 42     response.raise_for_status()
#      43     return np.array(response.json()[0])
#      44
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1022
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#    1026     def close(self):
#
# ...

# %%
from huggingface_hub import InferenceClient
from scipy.spatial.distance import cosine

client = InferenceClient(
    model="sentence-transformers/all-MiniLM-L6-v2",
    token="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"  # Replace with your token
)

# Sentences
source = "That is a happy person"
others = [
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]

# Get embeddings
source_embedding = client.text_embedding(source)
other_embeddings = [client.text_embedding(s) for s in others]

# Compute cosine similarity (1 - cosine distance)
similarities = [1 - cosine(source_embedding, emb) for emb in other_embeddings]

print(similarities)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-20-604339397.py in <cell line: 0>()
#      16
#      17 # Get embeddings
# ---> 18 source_embedding = client.text_embedding(source)
#      19 other_embeddings = [client.text_embedding(s) for s in others]
#      20
#
# AttributeError: 'InferenceClient' object has no attribute 'text_embedding'

# %%
import numpy as np
from huggingface_hub import InferenceClient

# Initialize client
client = InferenceClient(model="BAAI/bge-m3", token="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")

# Sentences to compare
sent1 = "That is a happy person"
sentences_to_compare = [
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]

# Get embeddings
embedding_1 = client.feature_extraction(sent1)
embeddings_2 = [client.feature_extraction(sent) for sent in sentences_to_compare]

# Compute cosine similarity
def cosine_similarity(vec1, vec2):
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Results
similarities = [cosine_similarity(embedding_1, e) for e in embeddings_2]
print(similarities)
# Out:
# [np.float32(0.8589123), np.float32(0.9666367), np.float32(0.7509794)]

# %%
from huggingface_hub import InferenceClient

# Initialize client
client = InferenceClient(
    model="BAAI/bge-m3",
    token="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"  # Replace with your actual Hugging Face token
)

# Input sentence
source_sentence = "That is a happy person"

# Sentences to compare
other_sentences = [
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]

# Perform sentence similarity
similarities = client.sentence_similarity(
    source_sentence,
    other_sentences
)

# Find the best match
best_index = similarities.index(max(similarities))
best_sentence = other_sentences[best_index]
best_score = similarities[best_index]

# Final result
print(f'✅ Best Match:\n"{best_sentence}" with a similarity score of {best_score:.4f}')
# Out:
# ✅ Best Match:
# "That is a very happy person" with a similarity score of 0.9666

# %%
from openai import OpenAI
from huggingface_hub import InferenceClient

# ------------------------
# API Keys (Replace these)
# ------------------------
openai_key = "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 "
hf_token = "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"

# ------------------------
# Create clients
# ------------------------
# For LLM responses (router to HF or Together endpoints)
llm_client = OpenAI(
    base_url="https://router.huggingface.co/v1",  # Can use Together if preferred
    api_key=openai_key
)

# For similarity comparison
similarity_client = InferenceClient(
    model="BAAI/bge-m3",
    token=hf_token
)

# ------------------------
# MCQ Question Prompt
# ------------------------
prompt = "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"

# ------------------------
# Models to query
# ------------------------
models = {
    "Phi-4": "microsoft/phi-4:nebius",
    "Nemotron": "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
}

answers = {}

# ------------------------
# Get answers from each LLM
# ------------------------
for name, model_id in models.items():
    try:
        response = llm_client.chat.completions.create(
            model=model_id,
            messages=[{"role": "user", "content": prompt}]
        )
        answer = response.choices[0].message.content.strip()
        answers[name] = answer
    except Exception as e:
        answers[name] = f"Error: {e}"

# ------------------------
# Sentence Similarity Check
# ------------------------
vals = list(answers.values())
if len(vals) < 2:
    print("❌ Not enough answers for comparison.")
else:
    # Perform sentence similarity
    source = vals[0]
    other = vals[1:]

    similarities = similarity_client.sentence_similarity(source, other)
    similarity_score = similarities[0]  # Compare first with second

    print("\n🔍 LLM Answer Comparison:\n")
    for name, answer in answers.items():
        print(f"{name} ➜ {answer}")

    # ------------------------
    # Final verdict based on similarity
    # ------------------------
    print("\n✅ Final Verdict:")
    if similarity_score > 0.9:
        print(f"\nBoth LLMs gave **similar answers** (score: {similarity_score:.4f})")
        print(f"\n🟢 Final Answer: {source}")
    else:
        print(f"\n⚠️ LLMs gave different answers (similarity score: {similarity_score:.4f})")
# Out:
# 🔍 LLM Answer Comparison:
#
# Phi-4 ➜ Error: Connection error.
# Nemotron ➜ Error: Connection error.
#
# ✅ Final Verdict:
#
# Both LLMs gave **similar answers** (score: 1.0000)
#
# 🟢 Final Answer: Error: Connection error.

# %%
from openai import OpenAI
from huggingface_hub import InferenceClient

# ------------------------
# API Keys (Replace these)
# ------------------------
openai_key = "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"
hf_token = "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"

# ------------------------
# Create clients
# ------------------------
llm_client = OpenAI(
    base_url="https://router.huggingface.co/v1",  # Use Together endpoint if needed
    api_key=openai_key
)

similarity_client = InferenceClient(
    model="BAAI/bge-m3",
    token=hf_token
)

# ------------------------
# MCQ Question Prompt
# ------------------------
prompt = "Q: Which planet is known as the Red Planet?\n\nA. Earth\nB. Mars\nC. Jupiter\nD. Venus"

models = {
    "Phi-4": "microsoft/phi-4:nebius",
    "Nemotron": "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
}

answers = {}

# ------------------------
# Get answers from LLMs
# ------------------------
for name, model_id in models.items():
    try:
        response = llm_client.chat.completions.create(
            model=model_id,
            messages=[{"role": "user", "content": prompt}]
        )
        answer = response.choices[0].message.content.strip()
        answers[name] = answer
    except Exception as e:
        answers[name] = f"Error: {str(e)}"

# ------------------------
# Display answers
# ------------------------
print("\n🔍 LLM Answer Comparison:\n")
for name, answer in answers.items():
    print(f"{name} ➜ {answer}")

# ------------------------
# Check for errors
# ------------------------
values = list(answers.values())
if any("Error" in val for val in values):
    print("\n❌ One or more LLMs failed to provide a response.")
    print("⚠️ Skipping similarity check.")
    print("\n🟡 Final Output: No valid answer to compare.")
else:
    # Run sentence similarity
    source = values[0]
    other = values[1:]

    similarities = similarity_client.sentence_similarity(source, other)
    score = similarities[0]

    # Final verdict
    print("\n✅ Final Verdict:")
    if score > 0.9:
        print(f"\nBoth LLMs gave **similar answers** (score: {score:.4f})")
        print(f"\n🟢 Final Answer: {source}")
    else:
        print(f"\n⚠️ LLMs gave different answers (similarity score: {score:.4f})")
# Out:
# 🔍 LLM Answer Comparison:
#
# Phi-4 ➜ B. Mars is known as the Red Planet due to its reddish appearance, which is caused by iron oxide, commonly known as rust, on its surface.
# Nemotron ➜ A simple and classic astronomy question!
#
# The correct answer is:
#
# **B. Mars**
#
# Explanation: Mars is commonly known as the "Red Planet" due to its distinctive reddish appearance, which is caused by iron oxide (or rust) in the planet's soil and rocks. This gives Mars its characteristic reddish hue, making it stand out in our solar system.
#
# ✅ Final Verdict:
#
# ⚠️ LLMs gave different answers (similarity score: 0.8648)

# %%
import re
from huggingface_hub import InferenceClient
from openai import OpenAI

# Set your Hugging Face Inference API key
HF_TOKEN = "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"

# === Question to ask ===
prompt = "Q: What gas do plants absorb from the atmosphere for photosynthesis?\n\nA. Oxygen\nB. Nitrogen\nC. Carbon Dioxide\nD. Hydrogen"

# === Define LLM models to query ===
models = {
    "Phi-4": "microsoft/phi-4:nebius",
    "Nemotron": "nvidia/Llama-3.1-Nemotron-70B-Instruct-HF:together"
}

# === Initialize clients ===
llm_client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=HF_TOKEN
)

# === Function to query LLM ===
def query_llm(model_id, question):
    try:
        response = llm_client.chat.completions.create(
            model=model_id,
            messages=[ {"role": "user", "content": question}]
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {e}"

# === Extract MCQ answer (e.g., "B. Mars") ===
def extract_answer(text):
    match = re.search(r"\b([A-D])[\.\)]\s*([^\n]*)", text)
    if match:
        return f"{match.group(1)}. {match.group(2).strip()}"
    return text.strip()[:50]

# === Function to compare using another LLM (Zephyr) ===
def judge_similarity_with_llm(ans1, ans2):
    judgment_prompt = f"""
Given the two multiple choice answers below, determine if they are the same answer (ignore explanations or additional text).

Answer 1: {ans1}
Answer 2: {ans2}

Respond with "Yes" if they refer to the same answer choice (like both are "B. Mars"). Otherwise, respond with "No".
    """.strip()

    try:
        response = llm_client.chat.completions.create(
            model="HuggingFaceH4/zephyr-7b-beta:featherless-ai",
            messages=[{"role": "user", "content": judgment_prompt}]
        )
        decision = response.choices[0].message.content.strip().lower()
        return "yes" in decision
    except Exception as e:
        print(f"Zephyr comparison failed: {e}")
        return False

# === Main Execution ===
answers = {}
stripped_answers = {}

print("🔍 LLM Answer Comparison:\n")

for name, model_id in models.items():
    raw = query_llm(model_id, prompt)
    parsed = extract_answer(raw)
    answers[name] = raw
    stripped_answers[name] = parsed
    print(f"{name} ➜ {parsed}")

# === Compare using Zephyr judgment ===
vals = list(stripped_answers.values())
same_answer = judge_similarity_with_llm(vals[0], vals[1])

print("\n✅ Final Verdict:\n")
if same_answer:
    print("✅ Both LLMs gave similar answers (according to Zephyr)")
    print(f"\n🟢 Final Answer: {vals[0]}")
else:
    print("⚠️ LLMs gave different answers according to Zephyr judgment.")
    for name, ans in stripped_answers.items():
        print(f"{name} ➜ {ans}")
# Out:
# 🔍 LLM Answer Comparison:
#
# Phi-4 ➜ C. Carbon Dioxide
# Nemotron ➜ C. Carbon Dioxide**
#
# ✅ Final Verdict:
#
# ⚠️ LLMs gave different answers according to Zephyr judgment.
# Phi-4 ➜ C. Carbon Dioxide
# Nemotron ➜ C. Carbon Dioxide**
